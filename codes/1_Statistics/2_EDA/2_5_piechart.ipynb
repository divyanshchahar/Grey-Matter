# %% [markdown]
# <h1> <u> EXPLORATORY DATA ANALYSIS - CHAPTER-2 - DEMO-5 </u> </h1>
# <h2> <u> Pie Chart </u> </h2>
#
# In this demo we will perform the following operations:
#
# - Title:
#     - set the title to "Carbon Footprint of Various Industries", fontsize to 20 and put the title 1.4 units above the plot

# %% [markdown]
# <h6> Importing Libraries </h6>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# <h6> Reading Dataset</h6>

# %%
df = pd.read_csv("ghg_by_sector.csv")
sectors = df["Sector"].values.tolist()
share = df["Share of global greenhouse gas emissions (%)"].values.tolist()

# %% [markdown]
# <h6> Plotting Graph </h6>

# %%
plt.pie(share, # list of values to be plotted
        labels=sectors, #Labels
        autopct='%1.1f%%', # Marking the portion of pie with its share value
        explode=(0.1, 0, 0, 0), # Drawing out the biggest portin of the pi
        startangle=0, # Starting position for plotting the pie chart
        rotatelabels=True, # Rotating labels
        radius=2) # Size of the Graph

plt.title("Carbon Footprint of Various Industries", fontsize=20, y=1.4)

plt.show()

# %% [markdown]
# <div class="alert alert-box alert-info">
#     <b>note</b> : This project will make use of <b> <i> matplotlib </i> </b> for visualization, however it is the obligation of the author ot point out that seaborn is also a very popular visualization library.
# </div>
